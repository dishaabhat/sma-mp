# %%
# !pip install selenium
# !pip install config
# !pip install selenium-stealth
# Out:
# Collecting selenium
#   Downloading selenium-4.31.0-py3-none-any.whl (9.4 MB)
#      ---------------------------------------- 9.4/9.4 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in d:\ana\lib\site-packages (from selenium) (2022.9.14)
# Collecting websocket-client~=1.8
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.8/58.8 kB 1.6 MB/s eta 0:00:00
# Collecting trio~=0.17
#   Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#      -------------------------------------- 492.9/492.9 kB 2.6 MB/s eta 0:00:00
# Collecting typing_extensions~=4.9
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.8/45.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in d:\ana\lib\site-packages (from selenium) (1.26.11)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: cffi>=1.14 in d:\ana\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in d:\ana\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in d:\ana\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting attrs>=23.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.8/63.8 kB 1.7 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\ana\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\ana\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: websocket-client, typing_extensions, sniffio, h11, exceptiongroup, attrs, wsproto, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
# Successfully installed attrs-25.3.0 exceptiongroup-1.2.2 h11-0.14.0 outcome-1.3.0.post0 selenium-4.31.0 sniffio-1.3.1 trio-0.29.0 trio-websocket-0.12.2 typing_extensions-4.13.2 websocket-client-1.8.0 wsproto-1.2.0
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# Collecting selenium-stealth
#   Downloading selenium_stealth-1.0.6-py3-none-any.whl (32 kB)
# Requirement already satisfied: selenium in d:\ana\lib\site-packages (from selenium-stealth) (4.31.0)
# Requirement already satisfied: typing_extensions~=4.9 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (1.8.0)
# Requirement already satisfied: trio~=0.17 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (0.12.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in d:\ana\lib\site-packages (from selenium->selenium-stealth) (2022.9.14)
# Requirement already satisfied: cffi>=1.14 in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.15.1)
# Requirement already satisfied: attrs>=23.2.0 in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (25.3.0)
# Requirement already satisfied: sniffio>=1.3.0 in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.3.1)
# Requirement already satisfied: outcome in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.3.0.post0)
# Requirement already satisfied: sortedcontainers in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (2.4.0)
# Requirement already satisfied: idna in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (3.3)
# Requirement already satisfied: exceptiongroup in d:\ana\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in d:\ana\lib\site-packages (from trio-websocket~=0.9->selenium->selenium-stealth) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\ana\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium->selenium-stealth) (1.7.1)
# Requirement already satisfied: pycparser in d:\ana\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->selenium-stealth) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\ana\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->selenium-stealth) (0.14.0)
# Installing collected packages: selenium-stealth
# Successfully installed selenium-stealth-1.0.6
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\ana\lib\site-packages)

# %%
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from time import sleep
import selenium.webdriver.common.keys
from selenium_stealth import stealth
from selenium.webdriver.support.ui import WebDriverWait
import time
import pandas as pd
import config
import random

# %%
import random
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium_stealth import stealth

# ---------- INLINE PROXY CONFIG ----------
# Add more proxies if needed 
ips =  ['161.35.70.249',
 '67.43.236.22',
 '172.188.122.92',
 '4.145.89.88',
 '46.47.197.210',
 '170.106.197.21',
 '49.51.188.4',
 '43.135.136.212',
 '43.130.9.63',
 '43.153.1.164',
 '95.216.148.196',
 '43.130.62.137',
 '43.135.154.71',
 '54.37.214.253',
 '81.169.213.169',
 '43.159.139.120',
 '195.114.209.50',
 '170.106.104.64',
 '134.209.29.120',
 '45.140.143.77',
 '43.130.12.65',
 '43.153.75.63',
 '43.153.32.146',
 '43.153.35.252',
 '43.153.61.52',
 '161.97.136.251',
 '107.150.105.176',
 '198.74.51.79',
 '43.159.148.136',
 '43.159.130.134',
 '143.42.66.91',
 '162.223.90.130',
 '97.74.87.226',
 '8.219.97.248',
 '5.160.224.146',
 '49.51.232.22',
 '43.153.27.172',
 '49.51.73.96',
 '188.166.56.246',
 '155.54.239.64',
 '219.65.73.81',
 '188.68.52.244',
 '49.51.250.156',
 '43.159.144.69',
 '43.135.177.135',
 '43.132.208.197',
 '164.90.242.76',
 '41.59.90.171',
 '128.59.17.185',
 '103.169.238.42',
 '2.59.181.248',
 '212.33.205.55',
 '103.156.16.193',
 '56.155.29.90',
 '43.153.112.164',
 '198.199.86.11',
 '8.215.15.163',
 '170.106.135.2',
 '13.38.153.36',
 '13.37.59.99',
 '13.38.176.104',
 '13.36.104.85',
 '13.36.87.105',
 '15.236.106.236',
 '203.115.101.51',
 '208.163.39.218',
 '43.153.27.248',
 '43.153.33.238',
 '43.135.129.37',
 '170.106.76.17',
 '43.135.139.98',
 '43.135.129.244',
 '43.153.101.244',
 '43.153.105.141',
 '3.124.133.93',
 '46.51.249.135',
 '3.12.144.146',
 '43.153.4.125',
 '43.153.45.169',
 '43.130.33.54',
 '3.130.65.162',
 '43.153.76.64',
 '43.153.23.242',
 '43.135.144.61',
 '52.201.245.219',
 '99.79.64.51',
 '13.115.194.123',
 '15.157.64.188',
 '15.152.54.90',
 '3.110.151.242',
 '50.169.37.50',
 '13.208.56.180',
 '43.202.154.212',
 '3.37.125.76',
 '43.201.121.81',
 '3.78.92.159',
 '15.152.203.118',
 '15.168.103.100',
 '13.54.47.197',
 '13.51.231.191',
 '15.237.115.153',
 '13.245.208.202',
 '51.16.199.206',
 '13.213.114.238',
 '51.16.179.113',
 '54.179.44.51',
 '16.16.239.39',
 '13.55.210.141',
 '54.152.3.36',
 '50.223.246.237',
 '133.18.234.13',
 '44.218.183.55',
 '66.191.31.158',
 '43.153.113.33',
 '15.168.57.13',
 '13.56.47.50',
 '3.97.167.115',
 '3.212.148.199',
 '3.90.100.12',
 '213.143.113.82',
 '150.136.247.129',
 '50.207.199.86',
 '191.52.236.39',
 '160.22.74.110',
 '193.33.153.47',
 '197.164.101.14',
 '103.36.10.27',
 '103.245.109.57',
 '91.184.243.186',
 '158.255.77.169',
 '13.250.172.255',
 '158.255.77.168',
 '18.138.124.192',
 '128.199.202.122',
 '203.115.101.53',
 '50.207.199.83',
 '50.174.7.153',
 '50.175.212.66',
 '50.217.226.40',
 '50.221.74.130',
 '190.58.248.86',
 '50.122.86.118',
 '184.169.154.119',
 '103.75.117.85',
 '128.199.98.132',
 '35.76.62.196',
 '43.200.77.128',
 '54.233.119.172',
 '52.196.1.182',
 '18.228.198.164',
 '52.67.10.183',
 '18.142.74.251',
 '13.246.209.48',
 '51.17.58.162',
 '43.153.88.167',
 '50.217.226.43',
 '50.239.72.17',
 '50.217.226.44',
 '204.236.137.68',
 '50.217.226.41',
 '211.128.96.206',
 '50.231.104.58',
 '50.174.7.156',
 '183.109.79.187',
 '103.155.168.155',
 '86.38.154.83',
 '193.233.137.15',
 '162.220.246.250',
 '104.238.10.79',
 '24.233.23.148']

def rand_proxy():
    proxy = random.choice(ips)
    return proxy

proxy = rand_proxy()

# ---------- CHROME OPTIONS ----------
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument(f'--proxy-server={proxy}')
chrome_options.add_argument("start-maximized")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option("useAutomationExtension", False)
chrome_options.page_load_strategy = 'normal'

# Brave browser path — only needed locally, not in Colab
chrome_options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"

# ---------- START WEBDRIVER ----------
driver = webdriver.Chrome(options=chrome_options)
stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine")

# Service instance (used when running locally)
s = Service("C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe")

new_data = []

# ---------- JOB SCRAPER FUNCTION ----------
def get_jobs():
    how_many_scrolls = 0
    driver.get("https://www.linkedin.com/jobs/search?keywords=data&location=India&geoId=102713980&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0")
    scroll_pause_time = 2
    scroll_height = 0
    
    while how_many_scrolls < 1:
        prev_scroll_height = scroll_height
        scroll_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script(f"window.scrollTo(0, {scroll_height});")
        time.sleep(scroll_pause_time)
        if scroll_height == prev_scroll_height:
            try:
                driver.find_element(By.CLASS_NAME, "infinite-scroller__show-more-button").click()
                how_many_scrolls += 1
            except:
                break

    jobs = driver.find_elements(By.XPATH, '//*[@id="main-content"]/section[2]/ul/li')  
    for noj in jobs:
        try:
            noj.click()
            time.sleep(2)
            job_name = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/section/div/div[1]/div/a/h2').text
            com_name = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/section/div/div[1]/div/h4/div[1]/span[1]/a').text
            loc = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/section/div/div[1]/div/h4/div[1]/span[2]').text
            job_level = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[1]/span').text
            job_type = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[2]/span').text
            job_func = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[3]/span').text
            job_ind = noj.find_element(By.XPATH, '/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[4]/span').text
            new_data.append([job_name, com_name, loc, job_level, job_func, job_type, job_ind])
        except:
            pass

    driver.quit()
    df1 = pd.DataFrame(new_data, columns=['Job_Title', 'Company', 'Location','Level', 'Type', 'Function','Industry'])
    df1.to_csv('linkedin_scraped_data.csv', index=False)

# ---------- RUN SCRAPER ----------
get_jobs()

# %%
#proxy
import requests, re
from bs4 import BeautifulSoup

regex = r"[0-9]+(?:\.[0-9]+){3}:[0-9]+"
c = requests.get("https://spys.me/proxy.txt")
test_str = c.text
a = re.finditer(regex, test_str, re.MULTILINE)
with open("proxies_list.txt", 'w') as file:
    for i in a:
       print(i.group(),file=file)
        
d = requests.get("https://free-proxy-list.net/")
soup = BeautifulSoup(d.content, 'html.parser')
td_elements = soup.select('.fpl-list .table tbody tr td')
ips = []
ports = []
for j in range(0, len(td_elements), 8):
    ips.append(td_elements[j].text.strip())
    ports.append(td_elements[j + 1].text.strip())
with open("proxies_list.txt", "a") as myfile:
    for ip, port in zip(ips, ports):
        proxy = f"{ip}:{port}"
        print(proxy, file=myfile)
